# %% [markdown]
# # Genera struttura dataset + labels come richiesto da ICAFusion

# %% [markdown]
# ```text
# Per primissima cosa definisci qui il path al dataset tuo personale relativo alla posizione di questo ipynb.
# Esempio:
# ADL-Project
#      kaist_cvpr15/
#             annotations...
#     kaist_change_structure.ipynb
#
# il mio dataset_path = "kaist-cvpr15"
# ```

# %%
from pathlib import Path

def set_dataset_path(path_str):
    """
    Imposta il path del dataset e restituisce un oggetto Path per il resto del notebook.
    """
    dataset_path = Path(path_str).expanduser().resolve()
    print(f"Percorso dataset impostato a:\n{dataset_path}")
    return dataset_path

# %%
dataset_path = set_dataset_path('kaist-cvpr15')  # Modifica questo percorso secondo le tue esigenze 

# Karolina /scratch/project/eu-25-19/kaist-cvpr15
# Out:
# Percorso dataset impostato a:
# /home/honey/ADL-Project/kaist-cvpr15

# %% [markdown]
# #### Dalle annotazioni XML alle annotazioni in formato YOLO (.txt)
# ```text
# - YOLO Format, alcuni dettagli :
#     Ogni immagine ha un file .txt con lo stesso nome dell’immagine, e dentro ci sono delle righe.
#     Ogni riga rappresenta un oggetto, con la seguente struttura:
#
#     <class_id> <x_center> <y_center> <width> <height>
#
#     - class_id → indice intero che rappresenta la classe (0,1,2,…).
#     - x_center, y_center → coordinate del centro della bounding box
#     - width, height → dimensioni della bounding box
#
#     I valori (x, y, w, h) sono sempre normalizzati e quindi compresi tra 0 e 1.
# ```

# %% [markdown]
# ### Indentificazione classi da XML
#
# ```text
# Come primo passo, utilizzando la lista dei sample destinati al training così da garantire imparzialita' al test set ed evitare l’inclusione dei dati usati nel pretraining SSL, identifichiamo tutte le label testuali uniche nelle nostre annotazioni XML, contandone per ciascuna la frequenza.
# ```
#
# --> lista target "Kaist_txt_lists/Training_split_25_forObjDet"

# %%
from pathlib import Path
import xml.etree.ElementTree as ET
from collections import defaultdict

def count_objects_from_list(annotation_file_name, list_path):
    """
    Conta le istanze di ciascuna classe solo per i sample elencati nella lista target.
    - annotation_file_name: nome del file dove si trovano le annotazioni XML (es: "annotations-xml-new")
    - list_path: Path del file contenente i sample da scandire (es: "Kaist_txt_lists/Training_split_25_forObjDet.txt")
    """
    base_dir = dataset_path / annotation_file_name
    list_path = Path(list_path)


    # Legge tutti i percorsi relativi dalla lista
    with open(list_path, "r") as f:
        relative_paths = [line.strip() for line in f if line.strip()]

    # Trova i file XML corrispondenti
    xml_files = []
    for rel_path in relative_paths:
        xml_file = base_dir / rel_path
        if not xml_file.suffix.lower() == ".xml":
            xml_file = xml_file.with_suffix(".xml")
        if xml_file.exists():
            xml_files.append(xml_file)
        else:
            print(f"File non trovato: {xml_file}")

    class_names = set()
    class_counts = defaultdict(int)

    print(f"Trovati {len(xml_files)} file XML dalla lista, inizio analisi...")

    for xml_path in xml_files:
        try:
            root = ET.parse(xml_path).getroot()
            for obj in root.findall("object"):
                name = (obj.findtext("name") or "").strip().lower()
                if name:
                    class_names.add(name)
                    class_counts[name] += 1
        except Exception as e:
            print(f"Errore nel file {xml_path}: {e}")

    print("Classi uniche trovate:")
    for cls in sorted(class_names):
        print(f"- {cls}")

    print("\nConteggio oggetti per classe:")
    for cls in sorted(class_counts):
        print(f"{cls}: {class_counts[cls]}")

# Esempio d'uso:
# count_objects_from_list("annotations-xml-new", "miei_sample.txt")

# %% [markdown]
# Esecuzione script precedente.
# ```
# N.B. Il path alla lista si presuppone univoca per tutti essendo tracciata da Git

# %%
count_objects_from_list("annotations-xml-new", "Kaist_txt_lists/Training_split_25_forObjDet.txt")
# Out:
# Trovati 26835 file XML dalla lista, inizio analisi...
# Classi uniche trovate:
# - cyclist
# - people
# - person
# - person?
#
# Conteggio oggetti per classe:
# cyclist: 2494
# people: 2805
# person: 23280
# person?: 720

# %%
#fast check per sanitized
count_objects_from_list("annotations-xml-new-sanitized", "Kaist_txt_lists/Training_split_25_forObjDet.txt")
# Out:
# Trovati 26835 file XML dalla lista, inizio analisi...
# Classi uniche trovate:
# - cyclist
# - people
# - person
# - person?
#
# Conteggio oggetti per classe:
# cyclist: 2494
# people: 2805
# person: 23280
# person?: 720

# %% [markdown]
# ### Funzione per convertire le annotazioni XML in YOLO

# %%
from pathlib import Path
import xml.etree.ElementTree as ET
import os

# Dizionario che mappa le classi testuali agli ID numerici YOLO 
CLASS_MAP = {
    "person": 0,  # sono le classi testuali nei file XML KAIST, mappate ad un ID numerico
    "people": 0,   # per ora unifichiamo in una sola classe tutte le buonding boxes
    "cyclist": 0, 
    "person?": 0  
}


def xml_dir_to_yolo_txt(xml_path, out_path):
    """
    - Input XML 
    - Output TXT (YOLO) 
    
    La struttura di cartelle è preservata.
    """
    
    try:
         # Parsing file XML, ottiene la radice
        root = ET.parse(xml_path).getroot()

        # Ottiene le dimensioni dell'immagine
        W = float(root.findtext("size/width"))
        H = float(root.findtext("size/height"))
        if W <= 0 or H <= 0:
            raise ValueError(f"Dimensioni non valide: W={W}, H={H}")

        lines = []
        for obj in root.findall("object"):
            # Prendi nome classe, rimuovi spazi e minuscolo
            name = (obj.findtext("name") or "").strip().lower()
            if name not in CLASS_MAP:
                # Salta classi non mappate (non dovrebbero esserci)
                continue
            cls_id = CLASS_MAP[name]

            
            # Estrai bbox (in pixel)
            b = obj.find("bndbox")
            x = float(b.findtext("x"))
            y = float(b.findtext("y"))
            w = float(b.findtext("w"))
            h = float(b.findtext("h"))

            # Clipping: calcola angoli, assicura che siano nel range immagine
            x1 = max(0.0, x)
            y1 = max(0.0, y)
            x2 = min(W, x + w)
            y2 = min(H, y + h)

            bw = x2 - x1
            bh = y2 - y1
            if bw <= 0 or bh <= 0:
                # Bbox degenerata o completamente fuori immagine
                continue
 
            # Calcola centro e normalizza
            cx = (x1 + x2) / 2.0 / W
            cy = (y1 + y2) / 2.0 / H
            bw_n = bw / W
            bh_n = bh / H
 
            # Clipping numerico in [0,1] per sicurezza
            cx = min(max(cx, 0.0), 1.0)
            cy = min(max(cy, 0.0), 1.0)
            bw_n = min(max(bw_n, 0.0), 1.0)
            bh_n = min(max(bh_n, 0.0), 1.0)

            # Prepara la riga formato YOLO pronta per il TXT
            lines.append(f"{int(cls_id)} {cx:.8f} {cy:.8f} {bw_n:.8f} {bh_n:.8f}")

            # lines.append(f"{int(cls_id)} {x:.6f} {y:.6f} {w:.6f} {h:.6f}")

        # Scrive nell'output preservando la struttura di cartelle
        # out_path = (out_dir / rel).with_suffix(".txt")
        out_path.parent.mkdir(parents=True, exist_ok=True)
        with open(out_path, "w", encoding="utf-8") as f:
            f.write("\n".join(lines))

    except Exception as e:
        # Avviso in caso di errore parsing/conversione
        print(f"[WARN] Errore su '{xml_path}': {e}")

# %% [markdown]
# ### Definizione input path e output path

# %%
from pathlib import Path
import os

#ricordo che abbiamo impostato precedentemente dataset_path

sanitized = False  # True se vuoi versione sanitized, False altrimenti

if not sanitized:
    xml_dir = dataset_path / "annotations-xml-new"
    txt_dir = dataset_path / "annotations-txt-new"
else:
    xml_dir = dataset_path / "annotations-xml-new-sanitized"
    txt_dir = dataset_path / "annotations-txt-new-sanitized"

os.makedirs(txt_dir, exist_ok=True)    # Crea la cartella di output se non esiste

# %%
from pathlib import Path

# xml_dir e txt_dir già definiti come Path, come da cella precedente


for dir in sorted(xml_dir.iterdir()):
    if dir.is_dir():
        print(f"Converting set: {dir.name}...")
        for subdir in sorted(dir.iterdir()):
            if subdir.is_dir():
                for file in sorted(subdir.iterdir()):
                    if file.is_file() and file.suffix.lower() == ".xml":
                        out_path = txt_dir / dir.name / subdir.name / file.with_suffix('.txt').name
                        xml_dir_to_yolo_txt(file, out_path)
# Out:
# Converting set: set00...
# Converting set: set01...
# Converting set: set02...
# Converting set: set03...
# Converting set: set04...
# Converting set: set05...
# Converting set: set06...
# Converting set: set07...
# Converting set: set08...
# Converting set: set09...
# Converting set: set10...
# Converting set: set11...

# %% [markdown]
# #### Conformity checks

# %% [markdown]
# 1) numero di oggetti == numero di righe nel txt

# %%
from pathlib import Path

sample = "set00/V000/I01216"

file_xml_path = xml_dir / (sample + ".xml")
file_txt_path = txt_dir / (sample + ".txt")


# Verifica esistenza file
assert file_xml_path.is_file(), f"File XML non trovato: {file_xml_path}"
assert file_txt_path.is_file(), f"File TXT non trovato: {file_txt_path}"

# Stampa contenuti
with open(file_xml_path, 'r', encoding='utf-8') as f:
    lines = f.readlines()
    xml_content = f.read()
    print("------ XML ORIGINALE ------")
    for line in lines[15:]:    # salto le prime 15 righe di header
        print(line, end='')

with open(file_txt_path, 'r', encoding='utf-8') as f:
    txt_content = f.read()
    print("\n------ TXT GENERATO ------")
    print(txt_content)
# Out:
# ------ XML ORIGINALE ------
#   <object>
#     <name>person</name>
#     <bndbox>
#       <x>194</x>
#       <y>213</y>
#       <w>20</w>
#       <h>42</h>
#     </bndbox>
#     <pose>unknown</pose>
#     <truncated>0</truncated>
#     <difficult>0</difficult>
#     <occlusion>0</occlusion>
#   </object>
#   <object>
#     <name>person</name>
#     <bndbox>
#       <x>209</x>
#       <y>215</y>
#       <w>21</w>
#       <h>43</h>
#     </bndbox>
#     <pose>unknown</pose>
#     <truncated>0</truncated>
#     <difficult>0</difficult>
#     <occlusion>0</occlusion>
#   </object>
# </annotation>
#
# ------ TXT GENERATO ------
# 0 0.31875000 0.45703125 0.03125000 0.08203125
# 0 0.34296875 0.46191406 0.03281250 0.08398438

# %% [markdown]
# 2) Se ripeto le trasformazioni sul singolo esempio XML estratto, effettivamente corrisponde a quanto calcolato in precedenza presente ora nel txt?

# %%
import xml.etree.ElementTree as ET

# Parsing XML
root = ET.parse(file_xml_path).getroot()
W = float(root.findtext("size/width"))
H = float(root.findtext("size/height"))

# Estrai bbox da XML
boxes = []
for obj in root.findall("object"):
    name = (obj.findtext("name") or "").strip().lower()
    b = obj.find("bndbox")
    x = float(b.findtext("x"))
    y = float(b.findtext("y"))
    w = float(b.findtext("w"))
    h = float(b.findtext("h"))
    # Stesse formule della funzione di conversione !
    x1 = max(0.0, x)
    y1 = max(0.0, y)
    x2 = min(W, x + w)
    y2 = min(H, y + h)
    bw = x2 - x1
    bh = y2 - y1
    if bw <= 0 or bh <= 0:
        continue
    cx = (x1 + x2)/2.0/W
    cy = (y1 + y2)/2.0/H
    bw_n = bw/W
    bh_n = bh/H
    cx = min(max(cx, 0.0), 1.0)
    cy = min(max(cy, 0.0), 1.0)
    bw_n = min(max(bw_n, 0.0), 1.0)
    bh_n = min(max(bh_n, 0.0), 1.0)
    boxes.append((name, cx, cy, bw_n, bh_n))

# Leggi il TXT generato dal convertitore
with open(file_txt_path, 'r', encoding='utf-8') as f:
    txt_lines = [line.strip() for line in f if line.strip()]

print("\nCONFRONTO BBOX (XML → calcolo Python → TXT):\n")

for i, (name, cx, cy, bw_n, bh_n) in enumerate(boxes):
    txt = txt_lines[i] if i < len(txt_lines) else "<NESSUNA RIGA>"
    print(f"BBox {i}: \nCalcolati: cx={cx:.8f} cy={cy:.8f} bw={bw_n:.8f} bh={bh_n:.8f}")
    vals = txt.split()
    print("dal txt:", " ".join(vals[1:]), "\n")
# Out:
# CONFRONTO BBOX (XML → calcolo Python → TXT):
#
# BBox 0:
# Calcolati: cx=0.31875000 cy=0.45703125 bw=0.03125000 bh=0.08203125
# dal txt: 0.31875000 0.45703125 0.03125000 0.08203125
#
# BBox 1:
# Calcolati: cx=0.34296875 cy=0.46191406 bw=0.03281250 bh=0.08398438
# dal txt: 0.34296875 0.46191406 0.03281250 0.08398438

# %%
sample = "set06/V000/I00259"
# sample = "set06_V000_I00339"

file_xml_path = os.path.join(xml_dir, sample.replace("_", "/") + '.xml')
file_txt_path = os.path.join(txt_dir, sample.replace("_", "/") + '.txt')
file_txt_example_from_icafusion = os.path.join("/scratch/project/eu-25-19/KAIST/labels/test/", sample.replace("/", "_") +".txt")

print(file_xml_path)
print(file_txt_path)

# controllo che i due file esistano:
assert os.path.isfile(file_xml_path), f"File XML non trovato: {file_xml_path}"
assert os.path.isfile(file_txt_path), f"File TXT non trovato: {file_txt_path}"

# stampa il contenuto dei due file:
with open(file_xml_path, 'r', encoding='utf-8') as f:
    xml_content = f.read()
    print("Contenuto XML:")
    print(xml_content)
with open(file_txt_path, 'r', encoding='utf-8') as f:
    txt_content = f.read()
    print("Contenuto TXT:")
    print(txt_content)
with open(file_txt_example_from_icafusion, 'r', encoding='utf-8') as f:
    txt_content = f.read()
    print("Contenuto TXT from icafusion:")
    print(txt_content)
# Out:
# /scratch/project/eu-25-19/kaist-cvpr15/annotations-xml-new/set06/V000/I00259.xml
# /scratch/project/eu-25-19/kaist-cvpr15/annotations-txt-new/set06/V000/I00259.txt
# Contenuto XML:
# <annotation>
#   <folder>KAIST Multispectral Ped Benchmark</folder>
#   <filename>set06/V000/I00259</filename>
#   <source>
#     <database>KAIST pedestrian</database>
#     <annotation>KAIST pedestrian</annotation>
#     KAIST pedestrian
#     <url>https://soonminhwang.github.io/rgbt-ped-detection/</url>
#   </source>
#   <size>
#     <width>640</width>
#     <height>512</height>
#     <depth>4</depth>
#   </size>
#   <segmented>0</segmented>
#   <object>
#     <name>person</name>
#     <bndbox>
#       <x>460</x>
#       <y>218</y>
#       <w>20</w>
#       <h>36</h>
#     </bndbox>
#     <pose>unknown</pose>
#     <truncated>0</truncated>
#     <difficult>0</difficult>
#     <occlusion>0</occlusion>
#   </object>
#   <object>
#     <name>person?</name>
#     <bndbox>
#       <x>72</x>
#       <y>202</y>
#       <w>33</w>
#       <h>51</h>
#     </bndbox>
#     <pose>unknown</pose>
#     <truncated>0</truncated>
#     <difficult>0</difficult>
#     <occlusion>0</occlusion>
#   </object>
# </annotation>
#
# Contenuto TXT:
# 0 0.734375 0.460938 0.031250 0.070312
# 0 0.138281 0.444336 0.051562 0.099609
# Contenuto TXT from icafusion:
# 0 0.734375 0.4609375 0.03125 0.0703125
# 0 0.13828125 0.4443359375 0.0515625 0.099609375

# %% [markdown]
# Perfetto tutto coerente!

# %% [markdown]
# ### Struttura dataset per ICAFusion
# ```text
# ICAFusion si aspetta il dataset kaist cosi diviso nelle seguenti cartelle
# visible/
#     train/    Contiene tutte le immagini visible senza alcuna divisione in set o video
#     test/
# Infrared/
#     train/    Contiene tutte le corrispondenti immagini infrared senza alcuna divisione in set o video
#     test/
# labels/
#     train/    Contiene tutte le corrispondenti annotazioni YOLO che abbiamo appena creato
#     test/
#
# Togliendo la divisione in set e video ogni immagine verra' identificata dal nuovo nome composto da SETxx_VYYY_Izzzzz
# ```

# %%
for mode in ["train", "test"]:
    (dataset_path / "visible" / mode).mkdir(parents=True, exist_ok=True)
    (dataset_path / "infrared" / mode).mkdir(parents=True, exist_ok=True)
    (dataset_path / "labels" / mode).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Riempimento cartelle dataset
# ```text
# Questo script legge due liste di sample (una per il training e una per il test),
# contenenti i path relativi ai sample (es: 'set06/V000/I00001'), e copia:
#     - le immagini visibili (“visible”) nelle rispettive cartelle (visible/train, visible/test)
#     - le immagini infrarosse (“infrared”) nelle rispettive cartelle (infrared/train, infrared/test)
#     - le label YOLO in formato .txt nelle rispettive cartelle (labels/train, labels/test)
#
# Il nome di ogni file copiato viene normalizzato in:
#     <set>_<video>_<immagine>.jpg (per visible e infrared)
#     <set>_<video>_<immagine>.txt (per labels)
# ```

# %%
from pathlib import Path
import shutil

def copy_all_samples_from_lists(train_list_path, test_list_path):
    """
    Copia immagini (visible, infrared) e label YOLO per i sample presenti nelle liste train/test.
    """
    datasets = {
        'train': train_list_path,
        'test': test_list_path
    }

    for subset, list_path in datasets.items():
        print(f"\n === PROCESSING {subset.upper()} SET ===")
        with open(list_path, "r") as f:
            samples = [line.strip() for line in f if line.strip()]

        for sample in samples:
            tokens = sample.split("/")
            if len(tokens) != 3:
                print(f"Formato sample non valido: {sample}")
                continue

            set_dir, v_dir, file_base = tokens
            # Formato immagini: Ixxxxx.jpg                  !!
            img_name = file_base + ".jpg"
            vis_path = dataset_path / "images" / set_dir / v_dir / "visible" / img_name
            lwir_path = dataset_path / "images" / set_dir / v_dir / "lwir" / img_name

            dest_vis = dataset_path / "visible" / subset / f"{set_dir}_{v_dir}_{img_name}"
            dest_lwir = dataset_path / "infrared" / subset / f"{set_dir}_{v_dir}_{img_name}"

            # Copia immagini visible
            if vis_path.is_file():
                if not dest_vis.is_file():
                    shutil.copy2(vis_path, dest_vis)
                else:
                    print(f"File visibile già esistente (skip): {dest_vis}")
            else:
                print(f"File visibile mancante: {vis_path}")

            # Copia immagini infrared
            if lwir_path.is_file():
                if not dest_lwir.is_file():
                    shutil.copy2(lwir_path, dest_lwir)
                else:
                    print(f"File lwir già esistente (skip): {dest_lwir}")
            else:
                print(f"File lwir mancante: {lwir_path}")

            # ===== LABELS =====
            orig_label = dataset_path / "annotations-txt-new" / set_dir / v_dir / (file_base + ".txt")
            dest_label = dataset_path / "labels" / subset / f"{set_dir}_{v_dir}_{file_base}.txt"
            if orig_label.is_file():
                if not dest_label.is_file():
                    shutil.copy2(orig_label, dest_label)
                else:
                    print(f"Label già esistente (skip): {dest_label}")
            else:
                print(f"Label mancante: {orig_label}")

# === ESEMPIO USO ===
# copy_all_samples_from_lists(dataset_path, "train_list.txt", "test_list.txt")

# %% [markdown]
# ```
# N.B. I path alle liste si presuppongono univoci per tutti essendo tracciati da Git

# %%
copy_all_samples_from_lists("Kaist_txt_lists/Training_split_25_forObjDet.txt", "Kaist_txt_lists/Test_split_50.txt")
# Out:
#  === PROCESSING TRAIN SET ===
#
#  === PROCESSING TEST SET ===

# %% [markdown]
# ### Conformity checks

# %% [markdown]
# ```text
# Verifichiamo:
# 1- Quanti file sono presenti nelle cartelle
#         * visible/train
#         * infrared/train
#         * labels/train
#     ! Coerente se uguale al numero di sample presenti nella lista di training utilizzata
# 2- Trova tutte le triplette di file che hanno lo stesso nome base (esclusa l'estensione)
#     ! Coerente se vengono individuate esattamente un numero di triplette pari al numero di sample nella lista di training utilizzata
# 3- Individuazione di eventuali file "orfani", cioè presenti solo in una o due delle cartelle.
#     ! Coerente se risulta uguale a zero
# ```

# %%
from pathlib import Path


visible_dir = dataset_path / "visible" / "train"
infrared_dir = dataset_path / "infrared" / "train"
labels_dir = dataset_path / "labels" / "train"

# Ottiene tutti i nomi file (senza estensione)
visible_files = {f.stem for f in visible_dir.iterdir() if f.is_file()}
infrared_files = {f.stem for f in infrared_dir.iterdir() if f.is_file()}
labels_files = {f.stem for f in labels_dir.iterdir() if f.is_file()}

print(f"File in visible/train:  {len(visible_files)}")
print(f"File in infrared/train: {len(infrared_files)}")
print(f"File in labels/train:   {len(labels_files)}")

# Intersezione: solo quelli che hanno lo stesso nome in tutte e tre le cartelle
triplette = visible_files & infrared_files & labels_files

print(f"\nNumero di triplette complete (stesso nome presente in tutte e tre le cartelle): {len(triplette)}")

# Chi manca in una delle tre cartelle
solo_vis = visible_files - triplette
solo_ir = infrared_files - triplette
solo_lbl = labels_files - triplette

print(f"\nSolo visible, non triplette: {len(solo_vis)}")
print(f"Solo infrared, non triplette: {len(solo_ir)}")
print(f"Solo labels, non triplette: {len(solo_lbl)}")
# Out:
# File in visible/train:  26835
# File in infrared/train: 26835
# File in labels/train:   26835
#
# Numero di triplette complete (stesso nome presente in tutte e tre le cartelle): 26835
#
# Solo visible, non triplette: 0
# Solo infrared, non triplette: 0
# Solo labels, non triplette: 0

# %% [markdown]
# Ripetiamo i checks anche sui sample del test set

# %%
from pathlib import Path


visible_dir = dataset_path / "visible" / "test"
infrared_dir = dataset_path / "infrared" / "test"
labels_dir = dataset_path / "labels" / "test"

# Ottiene tutti i nomi file (senza estensione)
visible_files = {f.stem for f in visible_dir.iterdir() if f.is_file()}
infrared_files = {f.stem for f in infrared_dir.iterdir() if f.is_file()}
labels_files = {f.stem for f in labels_dir.iterdir() if f.is_file()}

print(f"File in visible/train:  {len(visible_files)}")
print(f"File in infrared/train: {len(infrared_files)}")
print(f"File in labels/train:   {len(labels_files)}")

# Intersezione: solo quelli che hanno lo stesso nome in tutte e tre le cartelle
triplette = visible_files & infrared_files & labels_files

print(f"\nNumero di triplette complete (stesso nome presente in tutte e tre le cartelle): {len(triplette)}")

# Chi manca in una delle tre cartelle
solo_vis = visible_files - triplette
solo_ir = infrared_files - triplette
solo_lbl = labels_files - triplette

print(f"\nSolo visible, non triplette: {len(solo_vis)}")
print(f"Solo infrared, non triplette: {len(solo_ir)}")
print(f"Solo labels, non triplette: {len(solo_lbl)}")
# Out:
# File in visible/train:  45140
# File in infrared/train: 45140
# File in labels/train:   45140
#
# Numero di triplette complete (stesso nome presente in tutte e tre le cartelle): 45140
#
# Solo visible, non triplette: 0
# Solo infrared, non triplette: 0
# Solo labels, non triplette: 0

# %% [markdown]
# ```
# Test superati

# %% [markdown]
# # FINE

# %% [markdown]
# # Copio i file dal dataset originale alla "struttura" richiesta da icafusion

# %%
import shutil

test_sets_dir = ["set06", "set07", "set08", "set09", "set10", "set11"]
train_objsdet_sets_dir = ["set03", "set04", "set05"]
pretrain_sets_dir = ["set00", "set01", "set02"] # useless for Icafusion

# %% [markdown]
# # Copio le immagini:

# %%
for set_dir in sorted(os.listdir(KAIST_FOLDER + '/images')):
    if set_dir in test_sets_dir:
        subset = 'test'
    elif set_dir in train_objsdet_sets_dir:
        subset = 'train'
    elif set_dir in pretrain_sets_dir:
        # non ci interessa per icafusion
        continue
    else:
        print(f"Set non riconosciuto (skip): {set_dir}")
        continue

    print(f"Processing set: {set_dir} as {subset}...")
    for v_dir in sorted(os.listdir(os.path.join(KAIST_FOLDER, 'images', set_dir))):
        print(f" Processing subset: {v_dir}..")
        print(f"  Prossessin visible images...")
        for file in sorted(os.listdir(os.path.join(KAIST_FOLDER, 'images', set_dir, v_dir, "visible"))):
            file_path = os.path.join(KAIST_FOLDER, 'images', set_dir, v_dir, "visible", file)
            if os.path.isfile(file_path):
                dest_path = os.path.join(KAIST_FOLDER, 'visible', subset, f"{set_dir}_{v_dir}_{file}")
                if not os.path.isfile(dest_path):
                    shutil.copy2(file_path, dest_path)
                else:
                    print(f"File già esistente (skip): {dest_path}")

        print(f"  Prossessin infrared images...")
        for file in sorted(os.listdir(os.path.join(KAIST_FOLDER, 'images', set_dir, v_dir, "lwir"))):
            file_path = os.path.join(KAIST_FOLDER, 'images', set_dir, v_dir, "lwir", file)
            if os.path.isfile(file_path):
                dest_path = os.path.join(KAIST_FOLDER, 'infrared', subset, f"{set_dir}_{v_dir}_{file}")
                if not os.path.isfile(dest_path):
                    shutil.copy2(file_path, dest_path)
                else:
                    print(f"File già esistente (skip): {dest_path}")
# Out:
# Processing set: set11 as train...
#  Processing subset: V000..
#   Prossessin visible images...
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00000.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00001.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00002.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00003.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00004.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00005.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00006.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00007.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00008.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00009.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00010.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00011.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00012.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00013.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00014.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00015.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00016.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00017.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00018.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00019.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00020.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00021.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00022.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00023.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00024.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00025.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00026.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00027.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00028.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00029.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00030.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00031.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00032.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00033.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00034.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00035.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00036.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00037.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00038.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00039.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00040.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00041.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00042.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00043.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00044.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00045.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00046.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00047.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00048.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00049.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00050.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00051.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00052.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00053.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00054.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00055.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00056.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00057.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00058.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00059.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00060.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00061.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00062.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00063.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00064.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00065.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00066.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00067.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00068.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00069.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00070.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00071.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00072.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00073.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00074.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00075.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00076.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00077.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00078.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00079.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00080.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00081.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00082.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00083.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00084.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00085.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00086.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00087.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00088.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00089.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00090.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00091.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00092.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00093.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00094.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00095.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00096.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00097.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00098.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00099.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00100.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00101.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00102.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00103.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00104.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00105.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00106.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00107.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00108.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00109.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00110.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00111.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00112.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00113.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00114.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00115.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00116.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00117.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00118.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00119.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00120.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00121.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00122.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00123.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00124.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00125.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00126.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00127.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00128.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00129.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00130.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00131.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00132.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00133.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00134.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00135.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00136.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00137.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00138.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00139.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00140.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00141.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00142.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00143.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00144.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00145.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00146.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00147.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00148.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00149.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00150.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00151.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00152.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00153.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00154.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00155.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00156.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00157.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00158.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00159.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00160.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00161.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00162.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00163.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00164.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00165.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00166.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00167.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00168.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00169.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00170.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00171.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00172.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00173.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00174.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00175.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00176.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00177.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00178.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00179.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00180.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00181.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00182.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00183.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00184.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00185.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00186.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00187.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00188.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00189.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00190.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00191.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00192.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00193.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00194.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00195.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00196.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00197.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00198.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00199.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00200.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00201.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00202.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00203.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00204.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00205.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00206.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00207.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00208.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00209.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00210.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00211.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00212.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00213.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00214.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00215.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00216.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00217.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00218.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00219.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00220.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00221.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00222.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00223.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00224.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00225.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00226.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00227.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00228.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00229.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00230.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00231.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00232.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00233.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00234.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00235.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00236.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00237.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00238.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00239.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00240.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00241.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00242.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00243.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00244.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00245.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00246.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00247.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00248.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00249.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00250.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00251.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00252.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00253.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00254.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00255.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00256.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00257.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00258.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00259.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00260.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00261.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00262.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00263.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00264.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00265.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00266.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00267.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00268.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00269.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00270.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00271.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00272.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00273.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00274.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00275.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00276.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00277.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00278.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00279.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00280.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00281.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00282.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00283.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00284.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00285.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00286.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00287.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00288.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00289.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00290.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00291.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00292.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00293.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00294.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00295.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00296.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00297.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00298.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00299.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00300.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00301.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00302.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00303.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00304.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00305.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00306.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00307.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00308.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00309.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00310.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00311.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00312.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00313.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00314.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00315.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00316.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00317.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00318.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00319.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00320.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00321.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00322.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00323.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00324.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00325.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00326.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00327.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00328.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00329.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00330.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00331.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00332.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00333.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00334.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00335.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00336.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00337.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00338.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00339.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00340.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00341.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00342.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00343.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00344.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00345.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00346.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00347.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00348.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00349.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00350.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00351.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00352.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00353.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00354.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00355.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00356.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00357.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00358.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00359.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00360.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00361.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00362.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00363.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00364.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00365.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00366.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00367.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00368.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00369.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00370.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00371.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00372.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00373.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00374.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00375.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00376.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00377.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00378.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00379.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00380.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00381.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00382.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00383.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00384.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00385.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00386.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00387.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00388.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00389.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00390.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00391.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00392.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00393.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00394.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00395.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00396.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00397.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00398.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00399.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00400.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00401.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00402.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00403.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00404.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00405.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00406.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00407.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00408.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00409.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00410.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00411.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00412.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00413.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00414.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00415.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00416.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00417.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00418.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00419.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00420.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00421.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00422.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00423.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00424.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00425.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00426.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00427.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00428.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00429.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00430.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00431.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00432.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00433.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00434.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00435.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00436.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00437.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00438.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00439.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00440.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00441.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00442.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00443.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00444.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00445.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00446.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00447.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00448.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00449.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00450.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00451.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00452.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00453.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00454.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00455.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00456.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00457.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00458.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00459.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00460.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00461.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00462.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00463.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00464.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00465.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00466.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00467.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set03_V000_I00468.jpg
# ...
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00679.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00680.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00681.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00682.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00683.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00684.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00685.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00686.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00687.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00688.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00689.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00690.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00691.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00692.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00693.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00694.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00695.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00696.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00697.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00698.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00699.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00700.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00701.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00702.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00703.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00704.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00705.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00706.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00707.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00708.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00709.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00710.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00711.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00712.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00713.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00714.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00715.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00716.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00717.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00718.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00719.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00720.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00721.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00722.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00723.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00724.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00725.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00726.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00727.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00728.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00729.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00730.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00731.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00732.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00733.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00734.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00735.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00736.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00737.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00738.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00739.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00740.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00741.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00742.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00743.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00744.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00745.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00746.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00747.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00748.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00749.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00750.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00751.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00752.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00753.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00754.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00755.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00756.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00757.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00758.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00759.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00760.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00761.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00762.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00763.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00764.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00765.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00766.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00767.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00768.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00769.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00770.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00771.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00772.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00773.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00774.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00775.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00776.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00777.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00778.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00779.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00780.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00781.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00782.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00783.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00784.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00785.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00786.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00787.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00788.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00789.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00790.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00791.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00792.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00793.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00794.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00795.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00796.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00797.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00798.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00799.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00800.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00801.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00802.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00803.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00804.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00805.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00806.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00807.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00808.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00809.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00810.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00811.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00812.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00813.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00814.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00815.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00816.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00817.jpg
# File già esistente (skip): /scratch/project/eu-25-19/kaist-cvpr15/visible/train/set05_V000_I00818.jpg
#   Prossessin infrared images...
# Processing set: set11 as test...
#  Processing subset: V000..
#   Prossessin visible images...
#   Prossessin infrared images...
#  Processing subset: V001..
#   Prossessin visible images...
#   Prossessin infrared images...
#  Processing subset: V002..
#   Prossessin visible images...
#   Prossessin infrared images...
#  Processing subset: V003..
#   Prossessin visible images...
#   Prossessin infrared images...
#  Processing subset: V004..
#   Prossessin visible images...
#   Prossessin infrared images...
# Processing set: set11 as test...
#  Processing subset: V000..
#   Prossessin visible images...
#   Prossessin infrared images...
#  Processing subset: V001..
#   Prossessin visible images...
#   Prossessin infrared images...
#  Processing subset: V002..
#   Prossessin visible images...
#   Prossessin infrared images...
# Processing set: set11 as test...
#  Processing subset: V000..
#   Prossessin visible images...
#   Prossessin infrared images...
#  Processing subset: V001..
#   Prossessin visible images...
#   Prossessin infrared images...
#  Processing subset: V002..
#   Prossessin visible images...
#   Prossessin infrared images...
# Processing set: set11 as test...
#  Processing subset: V000..
#   Prossessin visible images...
#   Prossessin infrared images...
# Processing set: set11 as test...
#  Processing subset: V000..
#   Prossessin visible images...
#   Prossessin infrared images...
#  Processing subset: V001..
#   Prossessin visible images...
#   Prossessin infrared images...
# Processing set: set11 as test...
#  Processing subset: V000..
#   Prossessin visible images...
#   Prossessin infrared images...
#  Processing subset: V001..
#   Prossessin visible images...
#   Prossessin infrared images...

# %%
print(f"Prossessin label files...")

for set_dir in sorted(os.listdir(KAIST_FOLDER + '/annotations-txt-new')):
    if set_dir in test_sets_dir:
        subset = 'test'
    elif set_dir in train_objsdet_sets_dir:
        subset = 'train'
    elif set_dir in pretrain_sets_dir:
        # non ci interessa per icafusion
        continue
    else:
        print(f"Set non riconosciuto (skip): {set_dir}")
        continue

    
    print(f" Processing set: {set_dir} as {subset}...")
    for v_dir in sorted(os.listdir(os.path.join(KAIST_FOLDER, 'annotations-txt-new', set_dir))):
        print(f"  Processing subset: {v_dir}..")
        for file in sorted(os.listdir(os.path.join(KAIST_FOLDER, 'annotations-txt-new', set_dir, v_dir,))):
            file_path = os.path.join(KAIST_FOLDER, 'annotations-txt-new', set_dir, v_dir, file)
            if os.path.isfile(file_path):
                dest_path = os.path.join(KAIST_FOLDER, 'labels', subset, f"{set_dir}_{v_dir}_{file}")
                if not os.path.isfile(dest_path):
                    shutil.copy2(file_path, dest_path)
                else:
                    print(f"File già esistente (skip): {dest_path}")
# Out:
# Prossessin label files...
#  Processing set: set03 as train...
#   Processing subset: V000..
#   Processing subset: V001..
#  Processing set: set04 as train...
#   Processing subset: V000..
#   Processing subset: V001..
#  Processing set: set05 as train...
#   Processing subset: V000..
#  Processing set: set06 as test...
#   Processing subset: V000..
#   Processing subset: V001..
#   Processing subset: V002..
#   Processing subset: V003..
#   Processing subset: V004..
#  Processing set: set07 as test...
#   Processing subset: V000..
#   Processing subset: V001..
#   Processing subset: V002..
#  Processing set: set08 as test...
#   Processing subset: V000..
#   Processing subset: V001..
#   Processing subset: V002..
#  Processing set: set09 as test...
#   Processing subset: V000..
#  Processing set: set10 as test...
#   Processing subset: V000..
#   Processing subset: V001..
#  Processing set: set11 as test...
#   Processing subset: V000..
#   Processing subset: V001..

# %% [markdown]
# # Genero tutte la labels per icafusion e le salvo labels-for-icafusion (deprecato)

# %%
# !pwd
# 
# !cd /scratch/project/eu-25-19/kaist-cvpr15/
# 
# KAIST_FOLDER = '/scratch/project/eu-25-19/kaist-cvpr15/'
# os.makedirs(f'{KAIST_FOLDER}/labels-for-icafusion', exist_ok=True)
# Out:
# /mnt/proj3/eu-25-19/davide_secco/ADL-Project

# %%
# for dir in sorted(os.listdir(f'{KAIST_FOLDER}/annotations-xml-new')):
#     print(f"Convertig set: {dir}...")
#     for subdir in sorted(os.listdir(f'{KAIST_FOLDER}/annotations-xml-new/'+dir)):
#         print(f" Convertig subset: {subdir}..")
#         for file in sorted(os.listdir(os.path.join(f'{KAIST_FOLDER}/annotations-xml-new', dir, subdir))):
#             file_path = os.path.join(f'{KAIST_FOLDER}/annotations-xml-new', dir, subdir, file)
#             if os.path.isfile(file_path):
#                 xml_dir_to_yolo_txt(Path(file_path), Path(f'{KAIST_FOLDER}/labels-for-icafusion/'+dir+subdir+file.replace('.xml', '.txt')))
# Out:
# /mnt/proj3/eu-25-19/davide_secco/ADL-Project
# Convertig set: set00...
#  Convertig subset: V000..
#  Convertig subset: V001..
#  Convertig subset: V002..
#  Convertig subset: V003..
#  Convertig subset: V004..
#  Convertig subset: V005..
#  Convertig subset: V006..
#  Convertig subset: V007..
#  Convertig subset: V008..
# Convertig set: set01...
#  Convertig subset: V000..
#  Convertig subset: V001..
#  Convertig subset: V002..
#  Convertig subset: V003..
#  Convertig subset: V004..
#  Convertig subset: V005..
# Convertig set: set02...
#  Convertig subset: V000..
#  Convertig subset: V001..
#  Convertig subset: V002..
#  Convertig subset: V003..
#  Convertig subset: V004..
# Convertig set: set03...
#  Convertig subset: V000..
#  Convertig subset: V001..
# Convertig set: set04...
#  Convertig subset: V000..
#  Convertig subset: V001..
# Convertig set: set05...
#  Convertig subset: V000..
# Convertig set: set06...
#  Convertig subset: V000..
#  Convertig subset: V001..
#  Convertig subset: V002..
#  Convertig subset: V003..
#  Convertig subset: V004..
# Convertig set: set07...
#  Convertig subset: V000..
#  Convertig subset: V001..
#  Convertig subset: V002..
# Convertig set: set08...
#  Convertig subset: V000..
#  Convertig subset: V001..
#  Convertig subset: V002..
# Convertig set: set09...
#  Convertig subset: V000..
# Convertig set: set10...
#  Convertig subset: V000..
#  Convertig subset: V001..
# Convertig set: set11...
#  Convertig subset: V000..
#  Convertig subset: V001..

# %% [markdown]
# # Move the test-label to dedicated folder

# %%
# !pwd

os.chdir(f'{KAIST_FOLDER}')

# !ls -l

os.makedirs(f'{KAIST_FOLDER}/labels-test-icafusion', exist_ok=True)

# !mv 'labels-for-icafusion'/set06* labels-test-icafusion/ 
# !mv 'labels-for-icafusion'/set07* labels-test-icafusion/
# !mv 'labels-for-icafusion'/set08* labels-test-icafusion/
# !mv 'labels-for-icafusion'/set09* labels-test-icafusion/
# !mv 'labels-for-icafusion'/set10* labels-test-icafusion/
# !mv 'labels-for-icafusion'/set11* labels-test-icafusion/
# Out:
# /mnt/proj3/eu-25-19/davide_secco/ADL-Project
# total 10588
# drwxrws---+ 14 it4i-seccod eu-25-19    4096 Sep  5 16:07 annotations-xml-new
# drwxrws---+ 14 it4i-seccod eu-25-19    4096 Sep  5 15:29 annotations-xml-new-sanitized
# drwxrws---+  3 it4i-seccod eu-25-19    4096 Sep  5 16:14 davide_secco
# drwxrws---+ 14 it4i-seccod eu-25-19    4096 Sep  5 16:03 images
# drwxrws---+  3 it4i-seccod eu-25-19    4096 Sep  5 15:29 imageSets
# drwxrws---+  2 it4i-seccod eu-25-19  151552 Sep  5 15:26 kaist-dets
# -rw-rw----+  1 it4i-seccod eu-25-19  776816 Sep  5 15:26 kaist-dets.zip
# drwxrws---+  2 it4i-seccod eu-25-19 6684672 Sep  5 17:34 labels-for-icafusion
# drwxrws---+  2 it4i-seccod eu-25-19 3186688 Sep  5 17:34 labels-test-icafusion
# mv: cannot stat 'labels-for-icafusion/set06*': No such file or directory
# mv: cannot stat 'labels-for-icafusion/set07*': No such file or directory
# mv: cannot stat 'labels-for-icafusion/set08*': No such file or directory
# mv: cannot stat 'labels-for-icafusion/set09*': No such file or directory
# mv: cannot stat 'labels-for-icafusion/set10*': No such file or directory
# mv: cannot stat 'labels-for-icafusion/set11*': No such file or directory

# %%
# !pwd

# !ls images
# Out:
# /scratch/project/eu-25-19/kaist-cvpr15
# set00  set02  set04  set06  set08  set10
# set01  set03  set05  set07  set09  set11
