# %% [markdown]
# <a href="https://colab.research.google.com/github/DavideSecco/ADL-Project/blob/densecl-pretrain/densecl_pretrain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p /content/data

# %%
# !unzip -o /content/drive/MyDrive/datasets/data.zip -d /content/data
# Out:
# Archive:  /content/drive/MyDrive/datasets/data.zip
#    creating: /content/data/data/
#   inflating: /content/data/__MACOSX/._data
#   inflating: /content/data/data/.DS_Store
#   inflating: /content/data/__MACOSX/data/._.DS_Store
#    creating: /content/data/data/train/
#   inflating: /content/data/__MACOSX/data/._train
#   inflating: /content/data/data/train/.DS_Store
#   inflating: /content/data/__MACOSX/data/train/._.DS_Store
#    creating: /content/data/data/train/n01440764/
#   inflating: /content/data/__MACOSX/data/train/._n01440764
#    creating: /content/data/data/train/n01484850/
#   inflating: /content/data/__MACOSX/data/train/._n01484850
#   inflating: /content/data/data/train/n01440764/n01440764_6949.JPEG
#   inflating: /content/data/__MACOSX/data/train/n01440764/._n01440764_6949.JPEG
#   inflating: /content/data/data/train/n01440764/n01440764_4562.JPEG
#   inflating: /content/data/__MACOSX/data/train/n01440764/._n01440764_4562.JPEG
# ...

# %%
# !ls -R /content/data | head -n 40
# Out:
# /content/data:
# data
# __MACOSX
#
# /content/data/data:
# train
#
# /content/data/data/train:
# n01440764
# n01484850
#
# /content/data/data/train/n01440764:
# n01440764_10026.JPEG
# n01440764_10027.JPEG
# n01440764_10029.JPEG
# n01440764_10040.JPEG
# n01440764_10042.JPEG
# n01440764_10043.JPEG
# n01440764_10048.JPEG
# n01440764_10066.JPEG
# n01440764_10074.JPEG
# n01440764_10095.JPEG
# n01440764_1009.JPEG
# n01440764_10108.JPEG
# n01440764_10110.JPEG
# n01440764_10120.JPEG
# n01440764_10124.JPEG
# n01440764_10150.JPEG
# n01440764_10159.JPEG
# n01440764_10162.JPEG
# n01440764_10183.JPEG
# n01440764_10194.JPEG
# n01440764_1024.JPEG
# n01440764_105.JPEG
# n01440764_1063.JPEG
# n01440764_107.JPEG
# n01440764_1091.JPEG
# n01440764_1108.JPEG
# n01440764_1113.JPEG
# n01440764_1135.JPEG

# %%
# !mv /content/data/data/train /content/data/

# %%
# !rm -rf /content/data/data

# %%
# !rm -rf /content/data/__MACOSX

# %%
# !ls -R /content/data/train | head -n 40
# Out:
# /content/data/train:
# n01440764
# n01484850
#
# /content/data/train/n01440764:
# n01440764_10026.JPEG
# n01440764_10027.JPEG
# n01440764_10029.JPEG
# n01440764_10040.JPEG
# n01440764_10042.JPEG
# n01440764_10043.JPEG
# n01440764_10048.JPEG
# n01440764_10066.JPEG
# n01440764_10074.JPEG
# n01440764_10095.JPEG
# n01440764_1009.JPEG
# n01440764_10108.JPEG
# n01440764_10110.JPEG
# n01440764_10120.JPEG
# n01440764_10124.JPEG
# n01440764_10150.JPEG
# n01440764_10159.JPEG
# n01440764_10162.JPEG
# n01440764_10183.JPEG
# n01440764_10194.JPEG
# n01440764_1024.JPEG
# n01440764_105.JPEG
# n01440764_1063.JPEG
# n01440764_107.JPEG
# n01440764_1091.JPEG
# n01440764_1108.JPEG
# n01440764_1113.JPEG
# n01440764_1135.JPEG
# n01440764_1141.JPEG
# n01440764_1145.JPEG
# n01440764_1154.JPEG
# n01440764_1155.JPEG
# n01440764_1185.JPEG
# n01440764_1232.JPEG
# n01440764_1244.JPEG

# %%
# !pip install -r requirements.txt

# %%
# !python main.py /content/data \
  --multiprocessing-distributed \
  --world-size 1 \
  --rank 0 \
  --dist-url tcp://127.0.0.1:29500 \
  --epochs 200 \
  --batch-size 32 \
  --workers 4 \
  --mlp --aug-plus --cos \
  --use-mixed-precision
# Out:
# Use GPU: 0 for training
# => creating model 'resnet50'
# ... loading pre-trained weights ...
# [resnet50] pretrained weights loaded from https://download.pytorch.org/models/resnet50-19c8e357.pth
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /content/main.py:303: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = amp.GradScaler() if torch.cuda.is_available() else None
# ...
